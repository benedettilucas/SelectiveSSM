# %%
import torch
from s6_core.models import MambaVisionBase
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import torch
# ----> 2 from s6_core.models import MambaVisionBase
#
# File ~/Documentos/lucas-benedetti/03-mamba-models/pdi-mamba/core/matchers/SelectiveSSM/s6_core/models.py:7
#       5 from pathlib import Path
#       6 from einops import rearrange, repeat
# ----> 7 from s6_core.selective_scan_interface import selective_scan_fn
#       9 class MambaVisionBase(nn.Module):
#      10     def __init__(
#      11         self,
#      12         d_model,
#    (...)     27         dtype=None,
#      28     ):
#
# File ~/Documentos/lucas-benedetti/03-mamba-models/pdi-mamba/core/matchers/SelectiveSSM/s6_core/selective_scan_interface.py:20
#      16     causal_conv1d_update_function = None
#      18 from .layer_norm import _layer_norm_fwd
# ---> 20 import selective_scan_cuda
#      23 class SelectiveScanFn(torch.autograd.Function):
#      25     @staticmethod
#      26     def forward(ctx, u, delta, A, B, C, D=None, z=None, delta_bias=None, delta_softplus=False,
#      27                 return_last_state=False):
#
# ModuleNotFoundError: No module named 'selective_scan_cuda'

# %%
B = 1       # batch
L = 10000      # sequence length
D = 256     # d_model

hidden_states = torch.randn(B, L, D).cuda()  # IMPORTANT: cuda
print(hidden_states.shape)
model = MambaVisionBase(D).cuda()

# test forward
with torch.amp.autocast('cuda', enabled=False):
    out = model(hidden_states)
    

print("Output shape =", out.shape)
# Out:
# torch.Size([1, 10000, 256])
# Output shape = torch.Size([1, 10000, 256])
# /home/navms-pdi2/Documentos/lucas-benedetti/03-mamba-models/pdi-mamba/core/matchers/SelectiveSSM/s6_core/models.py:97: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1036.)
#   x = F.silu(F.conv1d(input=x, weight=self.conv1d_x.weight, bias=self.conv1d_x.bias, padding='same', groups=self.d_inner//2))
